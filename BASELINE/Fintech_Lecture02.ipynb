# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly
#   Downloading plotly-5.13.1-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 1.8 MB/s eta 0:00:0000:0100:01
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.13.1 tenacity-8.2.2

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import plotly.offline as py
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff
py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
os.getcwd()
# Out:
# '/Users/admin/Documents/GitHub/python_study'

# %%
os.chdir(os.path.join(os.getcwd(), 'DATA'))

# %%
df_airlines = pd.read_csv('airlines.csv', low_memory=False)
df_airports = pd.read_csv('airports.csv', low_memory=False)
df_flights = pd.read_csv('flights.csv', low_memory=False)

# %%
# 데이터 확인
print(df_airlines.head())
print(df_airports.head())
print(df_flights.head())
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                  NaN               NaN
# 1           -9.0         0          0                  NaN               NaN
# 2            5.0         0          0                  NaN               NaN
# 3           -9.0         0          0                  NaN               NaN
# 4          -21.0         0          0                  NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
# [5 rows x 31 columns]

# %%
# 데이터 크기 확인
print(df_airlines.shape)
print(df_airports.shape)
print(df_flights.shape)
# Out:
# (14, 2)
# (322, 7)
# (5819079, 31)

# %%
# 데이터 컬럼 확인
print(df_airlines.columns)
print(df_airports.columns)
print(df_flights.columns)
# Out:
# Index(['IATA_CODE', 'AIRLINE'], dtype='object')
# Index(['IATA_CODE', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE'],
#       dtype='object')
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
# 많이 쓰는 것
x = 'abc'
print(x.startswith('a')) # 시작하는 문자
print(x.endswith('a')) # 끝나는 문자
print(x.find('a')) # a가 몇번째에 있는지
print(x.replace('a', 'b')) # a를 b로 바꿔라
print(x.split('a')) # a를 기준으로 잘라서 리스트로 반환
print(x.upper()) # 대문자로
print(x.index('a')) # a가 몇번째에 있는지
# Out:
# True
# False
# 0
# bbc
# ['', 'bc']
# ABC

# %%
# 많이 쓰는 것 2
x = 'abc'
print(x.split()) # 공백을 기준으로 잘라서 리스트로 반환
print('%%%'.join(x)) # x를 %%%로 연결
# Out:
# ['abc']
# a%%%b%%%c

# %%
# datetime 사용법
import re
from datetime import datetime as dt
dt.strptime('2023-01-01', '%Y-%m-%d') - dt.strptime('2020-01-01', '%Y-%m-%d')

# %%
dt.strptime('2023-01-01', '%Y-%m-%d').strftime('%m/%d/%Y')
# Out:
# '01/01/2023'

# %%
# striptime에서 month 추출
dt.strptime('2023-01-01', '%Y-%m-%d').strftime('%m')
# Out:
# '01'

# %%
# EDA를 간편하게 해주는 패키지 
# !pip install fasteda
from fasteda import fast_eda
fast_eda(df_flights)
# Out:
# DataFrame Head:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 0            ANC                 SEA                    5          2354.0
# 1            LAX                 PBI                   10             2.0
# 2            SFO                 CLT                   20            18.0
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0        15.0           205.0         194.0
# 1             -8.0      12.0        14.0           280.0         279.0
# 2             -2.0      16.0        34.0           286.0         293.0
#
#    AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# 0     169.0      1448      404.0      4.0                430         408.0
# 1     263.0      2330      737.0      4.0                750         741.0
# 2     266.0      2296      800.0     11.0                806         811.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# DataFrame Tail:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 5819076            JFK                 SJU                 2359
# 5819077            MCO                 SJU                 2359
# 5819078            JFK                 BQN                 2359
#
#          DEPARTURE_TIME  DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  \
# 5819076          2350.0             -9.0      17.0         7.0
# 5819077          2353.0             -6.0      10.0         3.0
# 5819078            14.0             15.0      14.0        28.0
#
#          SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  \
# 5819076           221.0         222.0     197.0      1598      424.0      8.0
# 5819077           161.0         157.0     144.0      1189      327.0      3.0
# 5819078           221.0         208.0     189.0      1576      437.0      5.0
#
#          SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 5819076                440         432.0           -8.0         0          0
# 5819077                340         330.0          -10.0         0          0
# 5819078                440         442.0            2.0         0          0
#
#         CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 5819076                 NaN               NaN             NaN            NaN
# 5819077                 NaN               NaN             NaN            NaN
# 5819078                 NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 5819076                  NaN            NaN
# 5819077                  NaN            NaN
# 5819078                  NaN            NaN
# ----------------------------------------------------------------------------------------------------
# Missing values:
# <style type="text/css">
# #T_af42c_row0_col0, #T_af42c_row1_col0, #T_af42c_row2_col0, #T_af42c_row3_col0, #T_af42c_row4_col0, #T_af42c_row5_col0, #T_af42c_row6_col0, #T_af42c_row7_col0, #T_af42c_row8_col0, #T_af42c_row9_col0, #T_af42c_row10_col0, #T_af42c_row11_col0, #T_af42c_row12_col0, #T_af42c_row13_col0, #T_af42c_row14_col0, #T_af42c_row15_col0, #T_af42c_row16_col0, #T_af42c_row17_col0 {
#   background-color: #000000;
#   color: #ff0000;
#   font-weight: bold;
# }
# </style>
# <table id="T_af42c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af42c_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af42c_level0_row0" class="row_heading level0 row0" >TAIL_NUMBER</th>
#       <td id="T_af42c_row0_col0" class="data row0 col0" >14721</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row1" class="row_heading level0 row1" >DEPARTURE_TIME</th>
#       <td id="T_af42c_row1_col0" class="data row1 col0" >86153</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row2" class="row_heading level0 row2" >DEPARTURE_DELAY</th>
#       <td id="T_af42c_row2_col0" class="data row2 col0" >86153</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row3" class="row_heading level0 row3" >TAXI_OUT</th>
#       <td id="T_af42c_row3_col0" class="data row3 col0" >89047</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row4" class="row_heading level0 row4" >WHEELS_OFF</th>
#       <td id="T_af42c_row4_col0" class="data row4 col0" >89047</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row5" class="row_heading level0 row5" >SCHEDULED_TIME</th>
#       <td id="T_af42c_row5_col0" class="data row5 col0" >6</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row6" class="row_heading level0 row6" >ELAPSED_TIME</th>
#       <td id="T_af42c_row6_col0" class="data row6 col0" >105071</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row7" class="row_heading level0 row7" >AIR_TIME</th>
#       <td id="T_af42c_row7_col0" class="data row7 col0" >105071</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row8" class="row_heading level0 row8" >WHEELS_ON</th>
#       <td id="T_af42c_row8_col0" class="data row8 col0" >92513</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row9" class="row_heading level0 row9" >TAXI_IN</th>
#       <td id="T_af42c_row9_col0" class="data row9 col0" >92513</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row10" class="row_heading level0 row10" >ARRIVAL_TIME</th>
#       <td id="T_af42c_row10_col0" class="data row10 col0" >92513</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row11" class="row_heading level0 row11" >ARRIVAL_DELAY</th>
#       <td id="T_af42c_row11_col0" class="data row11 col0" >105071</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row12" class="row_heading level0 row12" >CANCELLATION_REASON</th>
#       <td id="T_af42c_row12_col0" class="data row12 col0" >5729195</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row13" class="row_heading level0 row13" >AIR_SYSTEM_DELAY</th>
#       <td id="T_af42c_row13_col0" class="data row13 col0" >4755640</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row14" class="row_heading level0 row14" >SECURITY_DELAY</th>
#       <td id="T_af42c_row14_col0" class="data row14 col0" >4755640</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row15" class="row_heading level0 row15" >AIRLINE_DELAY</th>
#       <td id="T_af42c_row15_col0" class="data row15 col0" >4755640</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row16" class="row_heading level0 row16" >LATE_AIRCRAFT_DELAY</th>
#       <td id="T_af42c_row16_col0" class="data row16 col0" >4755640</td>
#     </tr>
#     <tr>
#       <th id="T_af42c_level0_row17" class="row_heading level0 row17" >WEATHER_DELAY</th>
#       <td id="T_af42c_row17_col0" class="data row17 col0" >4755640</td>
#     </tr>
#   </tbody>
# </table>
# ----------------------------------------------------------------------------------------------------
# MSNO Matrix:
# ----------------------------------------------------------------------------------------------------
# Shape of DataFrame:
#
# (5819079, 31)
#
# ----------------------------------------------------------------------------------------------------
# DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
#  23  DIVERTED             int64
#  24  CANCELLED            int64
#  25  CANCELLATION_REASON  object
#  26  AIR_SYSTEM_DELAY     float64
#  27  SECURITY_DELAY       float64
#  28  AIRLINE_DELAY        float64
#  29  LATE_AIRCRAFT_DELAY  float64
#  30  WEATHER_DELAY        float64
# dtypes: float64(16), int64(10), object(5)
# memory usage: 1.3+ GB
# ----------------------------------------------------------------------------------------------------
# Describe DataFrame:
# <style type="text/css">
# #T_0cfd9_row0_col0, #T_0cfd9_row0_col2, #T_0cfd9_row0_col4, #T_0cfd9_row0_col5, #T_0cfd9_row0_col6, #T_0cfd9_row1_col0, #T_0cfd9_row2_col0, #T_0cfd9_row3_col0, #T_0cfd9_row4_col0, #T_0cfd9_row4_col1, #T_0cfd9_row4_col3, #T_0cfd9_row4_col7, #T_0cfd9_row4_col8, #T_0cfd9_row5_col0, #T_0cfd9_row10_col0, #T_0cfd9_row13_col0, #T_0cfd9_row16_col0, #T_0cfd9_row19_col0, #T_0cfd9_row20_col0 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row0_col1 {
#   background-color: #3f77b5;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row0_col3, #T_0cfd9_row1_col1, #T_0cfd9_row1_col3, #T_0cfd9_row1_col7, #T_0cfd9_row1_col8, #T_0cfd9_row2_col8, #T_0cfd9_row3_col1, #T_0cfd9_row3_col3, #T_0cfd9_row3_col7, #T_0cfd9_row3_col8, #T_0cfd9_row7_col2, #T_0cfd9_row7_col4, #T_0cfd9_row7_col6, #T_0cfd9_row7_col7, #T_0cfd9_row15_col1, #T_0cfd9_row15_col3, #T_0cfd9_row15_col7, #T_0cfd9_row18_col1, #T_0cfd9_row18_col2, #T_0cfd9_row18_col4, #T_0cfd9_row18_col5, #T_0cfd9_row18_col6, #T_0cfd9_row18_col7, #T_0cfd9_row19_col1, #T_0cfd9_row19_col2, #T_0cfd9_row19_col3, #T_0cfd9_row19_col6, #T_0cfd9_row19_col7, #T_0cfd9_row19_col8, #T_0cfd9_row20_col1, #T_0cfd9_row20_col2, #T_0cfd9_row20_col3, #T_0cfd9_row20_col6, #T_0cfd9_row20_col7, #T_0cfd9_row20_col8, #T_0cfd9_row21_col0, #T_0cfd9_row21_col2, #T_0cfd9_row21_col6, #T_0cfd9_row22_col0, #T_0cfd9_row22_col1, #T_0cfd9_row22_col2, #T_0cfd9_row22_col3, #T_0cfd9_row22_col6, #T_0cfd9_row22_col7, #T_0cfd9_row23_col0, #T_0cfd9_row23_col2, #T_0cfd9_row23_col6, #T_0cfd9_row24_col0, #T_0cfd9_row25_col0, #T_0cfd9_row25_col1, #T_0cfd9_row25_col2, #T_0cfd9_row25_col6, #T_0cfd9_row25_col7 {
#   background-color: #9e0142;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row0_col7, #T_0cfd9_row9_col1 {
#   background-color: #d8ef9b;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row0_col8 {
#   background-color: #f47044;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row0_col9, #T_0cfd9_row0_col10, #T_0cfd9_row19_col9, #T_0cfd9_row19_col10, #T_0cfd9_row20_col9, #T_0cfd9_row20_col10 {
#   color: #FFFFFF;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row1_col2, #T_0cfd9_row1_col6, #T_0cfd9_row2_col1, #T_0cfd9_row2_col3, #T_0cfd9_row2_col7, #T_0cfd9_row3_col2, #T_0cfd9_row3_col5, #T_0cfd9_row3_col6, #T_0cfd9_row7_col1, #T_0cfd9_row7_col5, #T_0cfd9_row8_col1, #T_0cfd9_row8_col3, #T_0cfd9_row8_col7, #T_0cfd9_row15_col2, #T_0cfd9_row15_col6, #T_0cfd9_row19_col5, #T_0cfd9_row20_col5, #T_0cfd9_row21_col1, #T_0cfd9_row21_col5, #T_0cfd9_row21_col7, #T_0cfd9_row22_col5, #T_0cfd9_row23_col5, #T_0cfd9_row23_col7, #T_0cfd9_row24_col2, #T_0cfd9_row24_col5, #T_0cfd9_row24_col6, #T_0cfd9_row25_col5 {
#   background-color: #a00343;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row1_col4, #T_0cfd9_row2_col4, #T_0cfd9_row3_col4, #T_0cfd9_row4_col4, #T_0cfd9_row5_col4, #T_0cfd9_row6_col4, #T_0cfd9_row8_col4, #T_0cfd9_row9_col4, #T_0cfd9_row10_col3, #T_0cfd9_row11_col3, #T_0cfd9_row12_col3, #T_0cfd9_row14_col4, #T_0cfd9_row15_col4, #T_0cfd9_row16_col4, #T_0cfd9_row17_col4, #T_0cfd9_row19_col4, #T_0cfd9_row20_col4, #T_0cfd9_row21_col4, #T_0cfd9_row22_col4, #T_0cfd9_row23_col4, #T_0cfd9_row24_col4, #T_0cfd9_row25_col4 {
#   background-color: #b41947;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row1_col5, #T_0cfd9_row2_col2, #T_0cfd9_row2_col5, #T_0cfd9_row2_col6, #T_0cfd9_row8_col2, #T_0cfd9_row8_col6, #T_0cfd9_row15_col5, #T_0cfd9_row23_col1, #T_0cfd9_row24_col1, #T_0cfd9_row24_col7, #T_0cfd9_row25_col3 {
#   background-color: #a20643;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row1_col9, #T_0cfd9_row2_col9, #T_0cfd9_row3_col9, #T_0cfd9_row4_col9, #T_0cfd9_row7_col9, #T_0cfd9_row7_col10, #T_0cfd9_row8_col9, #T_0cfd9_row8_col10, #T_0cfd9_row10_col9, #T_0cfd9_row10_col10, #T_0cfd9_row11_col9, #T_0cfd9_row11_col10, #T_0cfd9_row12_col9, #T_0cfd9_row12_col10, #T_0cfd9_row13_col9, #T_0cfd9_row13_col10, #T_0cfd9_row14_col10, #T_0cfd9_row15_col9, #T_0cfd9_row15_col10, #T_0cfd9_row16_col10, #T_0cfd9_row17_col10, #T_0cfd9_row18_col9, #T_0cfd9_row18_col10, #T_0cfd9_row21_col9, #T_0cfd9_row21_col10, #T_0cfd9_row22_col9, #T_0cfd9_row22_col10, #T_0cfd9_row23_col9, #T_0cfd9_row23_col10, #T_0cfd9_row24_col9, #T_0cfd9_row24_col10, #T_0cfd9_row25_col9, #T_0cfd9_row25_col10 {
#   color: #00ff00;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row1_col10, #T_0cfd9_row2_col10, #T_0cfd9_row3_col10, #T_0cfd9_row4_col10, #T_0cfd9_row5_col9, #T_0cfd9_row5_col10, #T_0cfd9_row6_col9, #T_0cfd9_row6_col10, #T_0cfd9_row9_col9, #T_0cfd9_row9_col10, #T_0cfd9_row14_col9, #T_0cfd9_row16_col9, #T_0cfd9_row17_col9 {
#   color: #ff0000;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row4_col2, #T_0cfd9_row4_col6 {
#   background-color: #52abae;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row4_col5 {
#   background-color: #fece7c;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row5_col1 {
#   background-color: #dff299;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row5_col2, #T_0cfd9_row5_col6 {
#   background-color: #c3e79f;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row5_col3 {
#   background-color: #fb9d59;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row5_col5, #T_0cfd9_row6_col5 {
#   background-color: #fff2aa;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row5_col7, #T_0cfd9_row6_col7 {
#   background-color: #f6fbb0;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row5_col8 {
#   background-color: #f8864f;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row6_col0, #T_0cfd9_row7_col0, #T_0cfd9_row8_col0, #T_0cfd9_row9_col0, #T_0cfd9_row14_col0, #T_0cfd9_row15_col0, #T_0cfd9_row17_col0 {
#   background-color: #5758a6;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row6_col1 {
#   background-color: #ddf19a;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row6_col2, #T_0cfd9_row6_col6 {
#   background-color: #c1e6a0;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row6_col3, #T_0cfd9_row9_col3 {
#   background-color: #fba35c;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row6_col8, #T_0cfd9_row9_col8, #T_0cfd9_row14_col8, #T_0cfd9_row16_col8, #T_0cfd9_row17_col8 {
#   background-color: #f88950;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row7_col3, #T_0cfd9_row8_col8, #T_0cfd9_row18_col3 {
#   background-color: #a90d45;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row7_col8, #T_0cfd9_row18_col8, #T_0cfd9_row23_col8 {
#   background-color: #f46d43;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row8_col5 {
#   background-color: #a40844;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row9_col2, #T_0cfd9_row9_col6 {
#   background-color: #bfe5a0;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row9_col5 {
#   background-color: #fff5ae;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row9_col7 {
#   background-color: #f4faad;
#   color: #000000;
#   font-weight: bold;
# }
# #T_0cfd9_row10_col1, #T_0cfd9_row10_col2, #T_0cfd9_row10_col6, #T_0cfd9_row11_col1 {
#   background-color: #c1274a;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row10_col4, #T_0cfd9_row10_col5, #T_0cfd9_row11_col4, #T_0cfd9_row12_col2, #T_0cfd9_row12_col6 {
#   background-color: #b81e48;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row10_col7, #T_0cfd9_row11_col7, #T_0cfd9_row12_col1, #T_0cfd9_row13_col4 {
#   background-color: #ba2049;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row10_col8 {
#   background-color: #c52c4b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row11_col0, #T_0cfd9_row12_col0, #T_0cfd9_row18_col0 {
#   background-color: #555aa7;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row11_col2, #T_0cfd9_row11_col6 {
#   background-color: #be254a;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row11_col5, #T_0cfd9_row12_col4, #T_0cfd9_row12_col7 {
#   background-color: #b61b48;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row11_col8 {
#   background-color: #c72e4c;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_0cfd9_row12_col5 {
#   background-color: #b11747;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# ----------------------------------------------------------------------------------------------------
# DataFrame Correlation:
# ----------------------------------------------------------------------------------------------------
# Histogram(s) & Boxplot(s):
# ----------------------------------------------------------------------------------------------------
# Countplot(s):
